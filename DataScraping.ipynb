# %% [markdown]
# **Extracting Data from Website**

# %%
# !pip install requests --upgrade

# %%
import requests
import time
import re
# import string

# %%
URL = "https://www.businesswire.com/portal/site/home/news/"
page = requests.get(URL)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.content,'html5lib')

# %%
news_items = soup.find_all(itemscope="itemscope")

# %%
news = {'date': [], 'time' : [], 'url' : [], 'content' : []}
for i in range(len(news_items)):
    if i&1 != 1:
        news['date'].append(news_items[i].find('time')['datetime'][:10])
        news['time'].append(news_items[i].find('time')['datetime'][11:-1])
        news['url'].append(news_items[i]['itemid'])
        news['content'].append('')

# %%
sep = ''
for i in range(len(news['url'])):
    temp = requests.get(news['url'][i])
    s = BeautifulSoup(temp.content,'html5lib')
    news['content'][i] += sep.join(i.getText() for i in s.find_all('p'))

# %% [markdown]
# All data stored in news & googletrans to translate non english articles

# %%
# !pip install googletrans
# from googletrans import Translator
# translator = Translator()

# %% [markdown]
# **Preprocessing and Cleaning**

# %%
# !pip install nltk --upgrade

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

sep = ' '
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

sentences = []

for i in range(len(news['content'])):
    sentences.append(sent_tokenize(news['content'][i]))

    # grading sentences
    temp = sentences[i][:]
    for j in range(len(temp)):
        temp[j] = temp[j].lower()
        temp[j] = re.sub(r'\d+', '', temp[j])           # Removing Numbers
        # temp[j] = temp[j].translate(string.maketrans("",""), string.punctuation)      # Removing Punctuations
        temp[j] = re.sub(r'[^\w\s]', '', temp[j])       # Removing Punctuations using Regex
        temp[j] = temp[j].strip()

        tokens = word_tokenize(temp[j])
        # pre_tagg = [stemmer.stem(r) for r in tokens if not r in stop_words]        # Stemming and removing stop words
        # OR
        pre_tagg = [lemmatizer.lemmatize(r) for r in tokens if not r in stop_words]        # Lemmatizing and removing stop words
        # pre_tagg = lemmatizer.lemmatize(tokens)
        tagged = nltk.pos_tag(pre_tagg)     # PoS Tagging

        temp[j] = sep.join([r[0] for r in tagged if r[1] in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'NN', 'NNS', 'NNP', 'NNPS']])   # Selecting only Verbs and Nouns
        
    sentences[i] = temp

# %%
# sep = ' '
# print(sep.join(nltk.RegexpTokenizer(r'\w+').tokenize(sentences[0])))

# %% [markdown]
# **TD-IDF Approach for Scoring**

# %%
# total_documents = len(sentences)
# total_documents
# Out:
# 25

# %%
def freq_matrix(sentences):
    matrix = {}

    for s in sentences:
        freq_table = {}
        words = word_tokenize(s)

        for w in words:
            if w in freq_table:
                freq_table[w] += 1
            else:
                freq_table[w] = 1
        
        matrix[s] = freq_table
    
    return matrix

# %%
print(freq_matrix(sentences[0]))
# Out:
# {'la primera compañía del sector bananero conseguir dole committed reaching water practice dolemanaged farm packing facility': {'la': 1, 'primera': 1, 'compañía': 1, 'del': 1, 'sector': 1, 'bananero': 1, 'conseguir': 1, 'dole': 1, 'committed': 1, 'reaching': 1, 'water': 1, 'practice': 1, 'dolemanaged': 1, 'farm': 1, 'packing': 1, 'facility': 1}, 'photo business wirecharlotte carolina del wiredole food company anunció hoy que fincas bananeras colombia do ecuador han logrado la certificación del estándar para la para alliance water stewardship fin nivel más alto proveedores dole': {'photo': 1, 'business': 1, 'wirecharlotte': 1, 'carolina': 1, 'del': 2, 'wiredole': 1, 'food': 1, 'company': 1, 'anunció': 1, 'hoy': 1, 'que': 1, 'fincas': 1, 'bananeras': 1, 'colombia': 1, 'do': 1, 'ecuador': 1, 'han': 1, 'logrado': 1, 'la': 2, 'certificación': 1, 'estándar': 1, 'para': 2, 'alliance': 1, 'water': 1, 'stewardship': 1, 'fin': 1, 'nivel': 1, 'más': 1, 'alto': 1, 'proveedores': 1, 'dole': 1}, 'el estándar tiene como beneficios sociales ambientales económicos paisaje que abarca todos captación lo que le comprender mejor cómo el del agua impacta trabajar colaborativa transparente para gestión del agua': {'el': 2, 'estándar': 1, 'tiene': 1, 'como': 1, 'beneficios': 1, 'sociales': 1, 'ambientales': 1, 'económicos': 1, 'paisaje': 1, 'que': 2, 'abarca': 1, 'todos': 1, 'captación': 1, 'lo': 1, 'le': 1, 'comprender': 1, 'mejor': 1, 'cómo': 1, 'del': 2, 'agua': 2, 'impacta': 1, 'trabajar': 1, 'colaborativa': 1, 'transparente': 1, 'para': 1, 'gestión': 1}, 'identificó conservación como la práctica más relevante e impactante toda sus operaciones': {'identificó': 1, 'conservación': 1, 'como': 1, 'la': 1, 'práctica': 1, 'más': 1, 'relevante': 1, 'e': 1, 'impactante': 1, 'toda': 1, 'sus': 1, 'operaciones': 1}, 'al adoptar este estándar dole sus productores avanzando progresivamente hacia gobernabilidad del agua aún más la del agua operaciones bananeras': {'al': 1, 'adoptar': 1, 'este': 1, 'estándar': 1, 'dole': 1, 'sus': 1, 'productores': 1, 'avanzando': 1, 'progresivamente': 1, 'hacia': 1, 'gobernabilidad': 1, 'del': 2, 'agua': 2, 'aún': 1, 'más': 1, 'la': 1, 'operaciones': 1, 'bananeras': 1}, 'conocimiento la compartirán regiones': {'conocimiento': 1, 'la': 1, 'compartirán': 1, 'regiones': 1}, 'logro dole sus productores con el fondo para la world fund nature al minorista con': {'logro': 1, 'dole': 1, 'sus': 1, 'productores': 1, 'con': 2, 'el': 1, 'fondo': 1, 'para': 1, 'la': 1, 'world': 1, 'fund': 1, 'nature': 1, 'al': 1, 'minorista': 1}, 'del más del agua el programa incluye la cultivo clima aspectos sociales': {'del': 2, 'más': 1, 'agua': 1, 'el': 1, 'programa': 1, 'incluye': 1, 'la': 1, 'cultivo': 1, 'clima': 1, 'aspectos': 1, 'sociales': 1}, 'claramente ahora hay presión sobre los recursos hídricos también impulsados por que historia': {'claramente': 1, 'ahora': 1, 'hay': 1, 'presión': 1, 'sobre': 1, 'los': 1, 'recursos': 1, 'hídricos': 1, 'también': 1, 'impulsados': 1, 'por': 1, 'que': 1, 'historia': 1}, 'la partes responsables incluidos agricultores comerciantes minoristas municipios ciudadanos individuales reconocen solo través la acción colectiva podemos mantener suministro robusto para señaló johannes alemania': {'la': 2, 'partes': 1, 'responsables': 1, 'incluidos': 1, 'agricultores': 1, 'comerciantes': 1, 'minoristas': 1, 'municipios': 1, 'ciudadanos': 1, 'individuales': 1, 'reconocen': 1, 'solo': 1, 'través': 1, 'acción': 1, 'colectiva': 1, 'podemos': 1, 'mantener': 1, 'suministro': 1, 'robusto': 1, 'para': 1, 'señaló': 1, 'johannes': 1, 'alemania': 1}, 'socios plantar estaca comprometerse hacer su parte hacia del que todos dependemos': {'socios': 1, 'plantar': 1, 'estaca': 1, 'comprometerse': 1, 'hacer': 1, 'su': 1, 'parte': 1, 'hacia': 1, 'del': 1, 'que': 1, 'todos': 1, 'dependemos': 1}, 'roussel food company declaró ha habido dependencia mutua vecinos pero esas relaciones al crear que dependen fuentes agua': {'roussel': 1, 'food': 1,  ...

# %%
def tf_matrix(freq_matrix):
    matrix = {}

    for sent, f_table in freq_matrix.items():
        table = {}

        count = len(f_table)
        for word, coun in f_table.items():
            table[word] = coun/count

        matrix[sent] = table
    
    return matrix

# %%
print(tf_matrix(freq_matrix(sentences[0])))
# Out:
# {'la primera compañía del sector bananero conseguir dole committed reaching water practice dolemanaged farm packing facility': {'la': 0.0625, 'primera': 0.0625, 'compañía': 0.0625, 'del': 0.0625, 'sector': 0.0625, 'bananero': 0.0625, 'conseguir': 0.0625, 'dole': 0.0625, 'committed': 0.0625, 'reaching': 0.0625, 'water': 0.0625, 'practice': 0.0625, 'dolemanaged': 0.0625, 'farm': 0.0625, 'packing': 0.0625, 'facility': 0.0625}, 'photo business wirecharlotte carolina del wiredole food company anunció hoy que fincas bananeras colombia do ecuador han logrado la certificación del estándar para la para alliance water stewardship fin nivel más alto proveedores dole': {'photo': 0.03225806451612903, 'business': 0.03225806451612903, 'wirecharlotte': 0.03225806451612903, 'carolina': 0.03225806451612903, 'del': 0.06451612903225806, 'wiredole': 0.03225806451612903, 'food': 0.03225806451612903, 'company': 0.03225806451612903, 'anunció': 0.03225806451612903, 'hoy': 0.03225806451612903, 'que': 0.03225806451612903, 'fincas': 0.03225806451612903, 'bananeras': 0.03225806451612903, 'colombia': 0.03225806451612903, 'do': 0.03225806451612903, 'ecuador': 0.03225806451612903, 'han': 0.03225806451612903, 'logrado': 0.03225806451612903, 'la': 0.06451612903225806, 'certificación': 0.03225806451612903, 'estándar': 0.03225806451612903, 'para': 0.06451612903225806, 'alliance': 0.03225806451612903, 'water': 0.03225806451612903, 'stewardship': 0.03225806451612903, 'fin': 0.03225806451612903, 'nivel': 0.03225806451612903, 'más': 0.03225806451612903, 'alto': 0.03225806451612903, 'proveedores': 0.03225806451612903, 'dole': 0.03225806451612903}, 'el estándar tiene como beneficios sociales ambientales económicos paisaje que abarca todos captación lo que le comprender mejor cómo el del agua impacta trabajar colaborativa transparente para gestión del agua': {'el': 0.07692307692307693, 'estándar': 0.038461538461538464, 'tiene': 0.038461538461538464, 'como': 0.038461538461538464, 'beneficios': 0.038461538461538464, 'sociales': 0.038461538461538464, 'ambientales': 0.038461538461538464, 'económicos': 0.038461538461538464, 'paisaje': 0.038461538461538464, 'que': 0.07692307692307693, 'abarca': 0.038461538461538464, 'todos': 0.038461538461538464, 'captación': 0.038461538461538464, 'lo': 0.038461538461538464, 'le': 0.038461538461538464, 'comprender': 0.038461538461538464, 'mejor': 0.038461538461538464, 'cómo': 0.038461538461538464, 'del': 0.07692307692307693, 'agua': 0.07692307692307693, 'impacta': 0.038461538461538464, 'trabajar': 0.038461538461538464, 'colaborativa': 0.038461538461538464, 'transparente': 0.038461538461538464, 'para': 0.038461538461538464, 'gestión': 0.038461538461538464}, 'identificó conservación como la práctica más relevante e impactante toda sus operaciones': {'identificó': 0.08333333333333333, 'conservación': 0.08333333333333333, 'como': 0.08333333333333333, 'la': 0.08333333333333333, 'práctica': 0.08333333333333333, 'más': 0.08333333333333333, 'relevante': 0.08333333333333333, 'e': 0.08333333333333333, 'impactante': 0.08333333333333333, 'toda': 0.08333333333333333, 'sus': 0.08333333333333333, 'operaciones': 0.08333333333333333}, 'al adoptar este estándar dole sus productores avanzando progresivamente hacia gobernabilidad del agua aún más la del agua operaciones bananeras': {'al': 0.05555555555555555, 'adoptar': 0.05555555555555555, 'este': 0.05555555555555555, 'estándar': 0.05555555555555555, 'dole': 0.05555555555555555, 'sus': 0.05555555555555555, 'productores': 0.05555555555555555, 'avanzando': 0.05555555555555555, 'progresivamente': 0.05555555555555555, 'hacia': 0.05555555555555555, 'gobernabilidad': 0.05555555555555555, 'del': 0.1111111111111111, 'agua': 0.1111111111111111, 'aún': 0.05555555555555555, 'más': 0.05555555555555555, 'la': 0.05555555555555555, 'operaciones': 0.05555555555555555, 'bananeras': 0.05555555555555555}, 'conocimiento la compartirán regiones': {'conocimiento': 0.25, 'la': 0.25, 'compartirán': 0.25, 'regiones': 0.25}, 'logro dol ...

# %%
def docs_per_word(freq_matrix):
    table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in table:
                table[word] += 1
            else:
                table[word] = 1
    return table

# %%
print(docs_per_word(freq_matrix(sentences[0])))
# Out:
# {'la': 9, 'primera': 1, 'compañía': 1, 'del': 8, 'sector': 1, 'bananero': 1, 'conseguir': 1, 'dole': 5, 'committed': 1, 'reaching': 1, 'water': 2, 'practice': 1, 'dolemanaged': 1, 'farm': 1, 'packing': 1, 'facility': 1, 'photo': 1, 'business': 1, 'wirecharlotte': 1, 'carolina': 1, 'wiredole': 1, 'food': 3, 'company': 3, 'anunció': 1, 'hoy': 1, 'que': 7, 'fincas': 2, 'bananeras': 2, 'colombia': 1, 'do': 1, 'ecuador': 1, 'han': 1, 'logrado': 1, 'certificación': 1, 'estándar': 3, 'para': 6, 'alliance': 1, 'stewardship': 1, 'fin': 1, 'nivel': 1, 'más': 7, 'alto': 1, 'proveedores': 1, 'el': 4, 'tiene': 1, 'como': 4, 'beneficios': 1, 'sociales': 2, 'ambientales': 1, 'económicos': 1, 'paisaje': 1, 'abarca': 1, 'todos': 3, 'captación': 1, 'lo': 1, 'le': 1, 'comprender': 1, 'mejor': 1, 'cómo': 1, 'agua': 4, 'impacta': 1, 'trabajar': 1, 'colaborativa': 1, 'transparente': 1, 'gestión': 1, 'identificó': 1, 'conservación': 1, 'práctica': 1, 'relevante': 1, 'e': 6, 'impactante': 1, 'toda': 1, 'sus': 3, 'operaciones': 2, 'al': 3, 'adoptar': 1, 'este': 1, 'productores': 2, 'avanzando': 1, 'progresivamente': 1, 'hacia': 2, 'gobernabilidad': 1, 'aún': 1, 'conocimiento': 1, 'compartirán': 1, 'regiones': 1, 'logro': 1, 'con': 2, 'fondo': 1, 'world': 1, 'fund': 1, 'nature': 1, 'minorista': 1, 'programa': 1, 'incluye': 1, 'cultivo': 1, 'clima': 1, 'aspectos': 1, 'claramente': 1, 'ahora': 1, 'hay': 1, 'presión': 1, 'sobre': 1, 'los': 1, 'recursos': 1, 'hídricos': 1, 'también': 1, 'impulsados': 1, 'por': 1, 'historia': 1, 'partes': 1, 'responsables': 1, 'incluidos': 1, 'agricultores': 1, 'comerciantes': 1, 'minoristas': 1, 'municipios': 1, 'ciudadanos': 1, 'individuales': 1, 'reconocen': 1, 'solo': 2, 'través': 1, 'acción': 1, 'colectiva': 1, 'podemos': 1, 'mantener': 1, 'suministro': 1, 'robusto': 1, 'señaló': 1, 'johannes': 1, 'alemania': 1, 'socios': 1, 'plantar': 1, 'estaca': 1, 'comprometerse': 1, 'hacer': 1, 'su': 1, 'parte': 1, 'dependemos': 1, 'roussel': 1, 'declaró': 1, 'ha': 1, 'habido': 1, 'dependencia': 1, 'mutua': 1, 'vecinos': 1, 'pero': 1, 'esas': 1, 'relaciones': 1, 'crear': 1, 'dependen': 1, 'fuentes': 1, 'importante': 1, 'pensar': 1, 'allá': 1, 'muchos': 1, 'problemas': 1, 'soluciones': 1, 'holísticas': 1, 'colaboraciones': 1, 'locale': 1, 'estrechas': 1, 'ofrecer': 1, 'mejoras': 1, 'acerca': 2, 'inc': 1, 'vegetales': 1, 'fresco': 1, 'calidad': 1, 'grandes': 1, 'mundo': 1, 'líder': 1, 'productos': 1, 'vende': 1, 'así': 1, 'obtener': 1, 'información': 1, 'visite': 1, 'wwwdolecom': 1, 'texto': 2, 'comunicado': 1, 'autorizada': 1, 'traducciones': 1, 'suministran': 1, 'adaptación': 1, 'deben': 1, 'cotejarse': 1, 'idioma': 1, 'fuente': 1, 'única': 1, 'versión': 1, 'tendrá': 1, 'contacto': 1, 'william': 1, 'goldfield': 1, 'williamgoldfielddolecom': 1}

# %%
import math
def idf_matrix(freq_matrix, docs_per_word, total_documents):

    matrix = {}

    for sent, f_table in freq_matrix.items():
        table = {}

        for word in f_table.keys():
            table[word] = math.log10(total_documents / float(docs_per_word[word]))

        matrix[sent] = table

    return matrix

# %%
print(idf_matrix(freq_matrix(sentences[0]), docs_per_word(freq_matrix(sentences[0])), len(sentences[0])))
# Out:
# {'la primera compañía del sector bananero conseguir dole committed reaching water practice dolemanaged farm packing facility': {'la': 0.3467874862246563, 'primera': 1.3010299956639813, 'compañía': 1.3010299956639813, 'del': 0.3979400086720376, 'sector': 1.3010299956639813, 'bananero': 1.3010299956639813, 'conseguir': 1.3010299956639813, 'dole': 0.6020599913279624, 'committed': 1.3010299956639813, 'reaching': 1.3010299956639813, 'water': 1.0, 'practice': 1.3010299956639813, 'dolemanaged': 1.3010299956639813, 'farm': 1.3010299956639813, 'packing': 1.3010299956639813, 'facility': 1.3010299956639813}, 'photo business wirecharlotte carolina del wiredole food company anunció hoy que fincas bananeras colombia do ecuador han logrado la certificación del estándar para la para alliance water stewardship fin nivel más alto proveedores dole': {'photo': 1.3010299956639813, 'business': 1.3010299956639813, 'wirecharlotte': 1.3010299956639813, 'carolina': 1.3010299956639813, 'del': 0.3979400086720376, 'wiredole': 1.3010299956639813, 'food': 0.8239087409443188, 'company': 0.8239087409443188, 'anunció': 1.3010299956639813, 'hoy': 1.3010299956639813, 'que': 0.45593195564972433, 'fincas': 1.0, 'bananeras': 1.0, 'colombia': 1.3010299956639813, 'do': 1.3010299956639813, 'ecuador': 1.3010299956639813, 'han': 1.3010299956639813, 'logrado': 1.3010299956639813, 'la': 0.3467874862246563, 'certificación': 1.3010299956639813, 'estándar': 0.8239087409443188, 'para': 0.5228787452803376, 'alliance': 1.3010299956639813, 'water': 1.0, 'stewardship': 1.3010299956639813, 'fin': 1.3010299956639813, 'nivel': 1.3010299956639813, 'más': 0.45593195564972433, 'alto': 1.3010299956639813, 'proveedores': 1.3010299956639813, 'dole': 0.6020599913279624}, 'el estándar tiene como beneficios sociales ambientales económicos paisaje que abarca todos captación lo que le comprender mejor cómo el del agua impacta trabajar colaborativa transparente para gestión del agua': {'el': 0.6989700043360189, 'estándar': 0.8239087409443188, 'tiene': 1.3010299956639813, 'como': 0.6989700043360189, 'beneficios': 1.3010299956639813, 'sociales': 1.0, 'ambientales': 1.3010299956639813, 'económicos': 1.3010299956639813, 'paisaje': 1.3010299956639813, 'que': 0.45593195564972433, 'abarca': 1.3010299956639813, 'todos': 0.8239087409443188, 'captación': 1.3010299956639813, 'lo': 1.3010299956639813, 'le': 1.3010299956639813, 'comprender': 1.3010299956639813, 'mejor': 1.3010299956639813, 'cómo': 1.3010299956639813, 'del': 0.3979400086720376, 'agua': 0.6989700043360189, 'impacta': 1.3010299956639813, 'trabajar': 1.3010299956639813, 'colaborativa': 1.3010299956639813, 'transparente': 1.3010299956639813, 'para': 0.5228787452803376, 'gestión': 1.3010299956639813}, 'identificó conservación como la práctica más relevante e impactante toda sus operaciones': {'identificó': 1.3010299956639813, 'conservación': 1.3010299956639813, 'como': 0.6989700043360189, 'la': 0.3467874862246563, 'práctica': 1.3010299956639813, 'más': 0.45593195564972433, 'relevante': 1.3010299956639813, 'e': 0.5228787452803376, 'impactante': 1.3010299956639813, 'toda': 1.3010299956639813, 'sus': 0.8239087409443188, 'operaciones': 1.0}, 'al adoptar este estándar dole sus productores avanzando progresivamente hacia gobernabilidad del agua aún más la del agua operaciones bananeras': {'al': 0.8239087409443188, 'adoptar': 1.3010299956639813, 'este': 1.3010299956639813, 'estándar': 0.8239087409443188, 'dole': 0.6020599913279624, 'sus': 0.8239087409443188, 'productores': 1.0, 'avanzando': 1.3010299956639813, 'progresivamente': 1.3010299956639813, 'hacia': 1.0, 'gobernabilidad': 1.3010299956639813, 'del': 0.3979400086720376, 'agua': 0.6989700043360189, 'aún': 1.3010299956639813, 'más': 0.45593195564972433, 'la': 0.3467874862246563, 'operaciones': 1.0, 'bananeras': 1.0}, 'conocimiento la compartirán regiones': {'conocimiento': 1.3010299956639813, 'la': 0.3467874862246563, 'compartirán': 1.3010299956639813, 'regiones': 1.3010299956639813}, 'logro dole su ...

# %%
def tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(), f_table2.items()):
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
print(tf_idf_matrix(tf_matrix(freq_matrix(sentences[0])), idf_matrix(freq_matrix(sentences[0]), docs_per_word(freq_matrix(sentences[0])), len(sentences[0]))))
# Out:
# {'la primera compañía del sector bananero conseguir dole committed reaching water practice dolemanaged farm packing facility': {'la': 0.02167421788904102, 'primera': 0.08131437472899883, 'compañía': 0.08131437472899883, 'del': 0.02487125054200235, 'sector': 0.08131437472899883, 'bananero': 0.08131437472899883, 'conseguir': 0.08131437472899883, 'dole': 0.03762874945799765, 'committed': 0.08131437472899883, 'reaching': 0.08131437472899883, 'water': 0.0625, 'practice': 0.08131437472899883, 'dolemanaged': 0.08131437472899883, 'farm': 0.08131437472899883, 'packing': 0.08131437472899883, 'facility': 0.08131437472899883}, 'photo business wirecharlotte carolina del wiredole food company anunció hoy que fincas bananeras colombia do ecuador han logrado la certificación del estándar para la para alliance water stewardship fin nivel más alto proveedores dole': {'photo': 0.041968709537547784, 'business': 0.041968709537547784, 'wirecharlotte': 0.041968709537547784, 'carolina': 0.041968709537547784, 'del': 0.02567354894658307, 'wiredole': 0.041968709537547784, 'food': 0.026577701320784474, 'company': 0.026577701320784474, 'anunció': 0.041968709537547784, 'hoy': 0.041968709537547784, 'que': 0.014707482440313687, 'fincas': 0.03225806451612903, 'bananeras': 0.03225806451612903, 'colombia': 0.041968709537547784, 'do': 0.041968709537547784, 'ecuador': 0.041968709537547784, 'han': 0.041968709537547784, 'logrado': 0.041968709537547784, 'la': 0.022373386208042342, 'certificación': 0.041968709537547784, 'estándar': 0.026577701320784474, 'para': 0.03373411259873146, 'alliance': 0.041968709537547784, 'water': 0.03225806451612903, 'stewardship': 0.041968709537547784, 'fin': 0.041968709537547784, 'nivel': 0.041968709537547784, 'más': 0.014707482440313687, 'alto': 0.041968709537547784, 'proveedores': 0.041968709537547784, 'dole': 0.019421290042837495}, 'el estándar tiene como beneficios sociales ambientales económicos paisaje que abarca todos captación lo que le comprender mejor cómo el del agua impacta trabajar colaborativa transparente para gestión del agua': {'el': 0.05376692341046299, 'estándar': 0.03168879772862765, 'tiene': 0.05003961521784544, 'como': 0.026883461705231496, 'beneficios': 0.05003961521784544, 'sociales': 0.038461538461538464, 'ambientales': 0.05003961521784544, 'económicos': 0.05003961521784544, 'paisaje': 0.05003961521784544, 'que': 0.035071688896132644, 'abarca': 0.05003961521784544, 'todos': 0.03168879772862765, 'captación': 0.05003961521784544, 'lo': 0.05003961521784544, 'le': 0.05003961521784544, 'comprender': 0.05003961521784544, 'mejor': 0.05003961521784544, 'cómo': 0.05003961521784544, 'del': 0.030610769897849048, 'agua': 0.05376692341046299, 'impacta': 0.05003961521784544, 'trabajar': 0.05003961521784544, 'colaborativa': 0.05003961521784544, 'transparente': 0.05003961521784544, 'para': 0.020110720972320677, 'gestión': 0.05003961521784544}, 'identificó conservación como la práctica más relevante e impactante toda sus operaciones': {'identificó': 0.10841916630533177, 'conservación': 0.10841916630533177, 'como': 0.0582475003613349, 'la': 0.028898957185388027, 'práctica': 0.10841916630533177, 'más': 0.03799432963747702, 'relevante': 0.10841916630533177, 'e': 0.043573228773361464, 'impactante': 0.10841916630533177, 'toda': 0.10841916630533177, 'sus': 0.06865906174535989, 'operaciones': 0.08333333333333333}, 'al adoptar este estándar dole sus productores avanzando progresivamente hacia gobernabilidad del agua aún más la del agua operaciones bananeras': {'al': 0.04577270783023993, 'adoptar': 0.0722794442035545, 'este': 0.0722794442035545, 'estándar': 0.04577270783023993, 'dole': 0.03344777729599791, 'sus': 0.04577270783023993, 'productores': 0.05555555555555555, 'avanzando': 0.0722794442035545, 'progresivamente': 0.0722794442035545, 'hacia': 0.05555555555555555, 'gobernabilidad': 0.0722794442035545, 'del': 0.04421555651911529, 'agua': 0.0776633338151132, 'aún': 0.0722794442035545, 'más': 0.02532955309165135, 'la': 0.019265971456925 ...

# %%
def score_sentences(tf_idf_matrix) -> dict:
    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score

        sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence

    return sentenceValue

# %%
sentence_scores = score_sentences(tf_idf_matrix(tf_matrix(freq_matrix(sentences[0])), idf_matrix(freq_matrix(sentences[0]), docs_per_word(freq_matrix(sentences[0])), len(sentences[0]))))

# %%
def average_score(sentenceValue) -> int:
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    average = (sumValues / len(sentenceValue))

    return average

# %%
print(average_score(sentence_scores))
# Out:
# 0.131844550056537

# %%
def generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:15] in sentenceValue and sentenceValue[sentence[:15]] >= (threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary
